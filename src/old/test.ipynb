# %%
import os
import sys
import pandas as pd

# Get the absolute path to the src directory
src_path = os.path.abspath(os.path.join(os.getcwd(), "../"))

# Add src_path to the system path
sys.path.insert(0, src_path)

# Now you can import your module
import scripts.graph_utils as gru
import scripts.graph_tests as gat

# %% [markdown]
# # Star Graph

# %%
graph = gru.read_directed_graph_from_edge_list("../../data/tests/star.edges")
gru.draw_graph(graph)

# %%
subgraph = gru.read_directed_graph_from_edge_list(
    "../../data/motif_test/star-motif.edges"
)
gru.draw_graph(subgraph)

# %% [markdown]
# ## Anchored

# %%
gru.subgraph_count(graph, [subgraph], anchored=True)
# Out:
# Generating subgraphs of size  7
# Generated  1  subgraphs
# {0: 1}

# %% [markdown]
# ## Graph Level

# %%
gru.subgraph_count(graph, [subgraph], anchored=False)
# Out:
# Generating subgraphs of size  7
# Generated  3003  subgraphs
# {0: 3003}

# %%
gat.subgraph_count(graph, [subgraph], anchored=False)
# Out:
# Generating subgraphs of size  7
# Generated  1  subgraphs
# {0: 3003}

# %% [markdown]
# # Synthetic Graph

# %%
graph = gru.read_directed_graph_from_edge_list("../../data/twitter_samples/7861312_sample_sff_10.edges")
gru.draw_graph(graph)

# %%
motifs = gru.read_graphs_from_directory("../../data/motifs_3")

# %%
gru.subgraph_count(graph, motifs.values(), anchored=False)
# Out:
# Generating subgraphs of size  3
# Generated  355  subgraphs
# {0: 24,
#  1: 69,
#  2: 87,
#  3: 15,
#  4: 15,
#  5: 49,
#  6: 44,
#  7: 0,
#  8: 3,
#  9: 19,
#  10: 16,
#  11: 11,
#  12: 3}

# %%
gat.subgraph_count(graph, motifs.values(), anchored=False)
# Out:
# Generating subgraphs of size  3
# Generated  12  subgraphs
# {0: 24,
#  1: 69,
#  2: 87,
#  3: 15,
#  4: 15,
#  5: 49,
#  6: 44,
#  7: 0,
#  8: 3,
#  9: 19,
#  10: 16,
#  11: 11,
#  12: 3}

# %%
gru.subgraph_count(graph, motifs.values(), anchored=True)
# Out:
# Generating subgraphs of size  3
# Generated  16  subgraphs
# {0: 6,
#  1: 9,
#  2: 9,
#  3: 4,
#  4: 2,
#  5: 10,
#  6: 7,
#  7: 0,
#  8: 5,
#  9: 11,
#  10: 6,
#  11: 13,
#  12: 4}

# %%
for sb in gru.generate_anchored_subgraphs(
    graph, max([subgraph.number_of_nodes() for subgraph in motifs.values()])
):
    gru.draw_graph(sb)
