# %%
import os
import sys
import pandas as pd

# Get the absolute path to the src directory
src_path = os.path.abspath(os.path.join(os.getcwd(), "../"))

# Add src_path to the system path
sys.path.insert(0, src_path)

# Now you can import your module
import scripts.graph_utils as gru

# %%
graph = gru.read_directed_graph_from_edge_list('../../data/tests/no-anchor.edges')
gru.draw_graph(graph)

# %%
subgraph = gru.read_directed_graph_from_edge_list('../../data/tests/no-anchor-motif.edges')
gru.draw_graph(subgraph)

# %%
gru.subgraph_count(graph, [subgraph])
# Out:
# Generating subgraphs of size  4
# Generated 31 subgraphs
# {0: 21}

# %%
for s in gru.generate_anchored_subgraphs(graph, len(subgraph.nodes())):
    gru.draw_graph(s)

# %%
gru.subgraph_count(graph, [subgraph], anchored=True)
# Out:
# Generating subgraphs of size  4
# Generated 2 subgraphs
# {0: 1}
